# %%
import pandas as pd
import numpy as np
import pickle
from cesium.featurize import featurize_time_series
import tqdm

# Load train curves
df = pd.read_csv('../data/training_set.csv',
                 dtype={
            'object_id': np.int32,
            'mjd': np.float32,
            'passband': np.int8,
            'flux': np.float32,
            'flux_err': np.float32,
            'detected': np.uint8,
        })

# %%
df_gb = df.groupby(['object_id', 'passband'])
uoids = df['object_id'].unique()
passbands = range(6)
grouped_ts = []

for series in tqdm.tqdm(['mjd', 'flux', 'flux_err'], total=3):
    oi_group = []
    for oid in uoids:
        pb_group = []
        for pb in passbands:
            pb_group.append(df_gb.get_group((oid, pb))[series].values.astype('double'))
        oi_group.append(pb_group)
    grouped_ts.append(oi_group)
    
t, v, e = grouped_ts
# Out:
# 100%|██████████| 3/3 [00:56<00:00, 18.79s/it]

# %%
# %%time
with open('./data/t_exp.pkl', 'wb') as handle:
    pickle.dump(t, handle)
# Out:
# CPU times: user 159 ms, sys: 8.08 ms, total: 167 ms
# Wall time: 165 ms

# %%
# %%time
with open('./data/t_exp.pkl', 'rb') as handle:
    t_loaded = pickle.load(handle)
# Out:
# CPU times: user 79.7 ms, sys: 4 ms, total: 83.7 ms
# Wall time: 82 ms

# %%
# %%time

feat_names = [
    'amplitude',
#     'flux_percentile_ratio_mid20',
#     'flux_percentile_ratio_mid35',
#     'flux_percentile_ratio_mid50',
#     'flux_percentile_ratio_mid65',
#     'flux_percentile_ratio_mid80',
    'max_slope',
    'maximum',
    'median',
    'median_absolute_deviation',
    'minimum',
#     'percent_amplitude',
    'percent_beyond_1_std',
    'percent_close_to_median',
#     'percent_difference_flux_percentile',
    'period_fast',
    'qso_log_chi2_qsonu',
    'qso_log_chi2nuNULL_chi2nu',
    'skew',
    'std',
    'stetson_j',
    'stetson_k',
    'weighted_average',
    'all_times_nhist_numpeaks',
    'all_times_nhist_peak1_bin',
    'all_times_nhist_peak2_bin',
    'all_times_nhist_peak3_bin',
    'all_times_nhist_peak4_bin',
    'all_times_nhist_peak_1_to_2',
    'all_times_nhist_peak_1_to_3',
    'all_times_nhist_peak_1_to_4',
    'all_times_nhist_peak_2_to_3',
    'all_times_nhist_peak_2_to_4',
    'all_times_nhist_peak_3_to_4',
    'all_times_nhist_peak_val',
    'avg_double_to_single_step',
    'avg_err',
    'avgt',
    'cad_probs_1',
    'cad_probs_10',
    'cad_probs_20',
    'cad_probs_30',
    'cad_probs_40',
    'cad_probs_50',
    'cad_probs_100',
    'cad_probs_500',
    'cad_probs_1000',
    'cad_probs_5000',
    'cad_probs_10000',
    'cad_probs_50000',
    'cad_probs_100000',
    'cad_probs_500000',
    'cad_probs_1000000',
    'cad_probs_5000000',
    'cad_probs_10000000',
    'cads_avg',
    'cads_med',
    'cads_std',
    'mean',
    'med_double_to_single_step',
    'med_err',
    'n_epochs',
    'std_double_to_single_step',
    'std_err',
    'total_time',
    'fold2P_slope_10percentile',
    'fold2P_slope_90percentile',
    'freq1_amplitude1',
    'freq1_amplitude2',
    'freq1_amplitude3',
    'freq1_amplitude4',
    'freq1_freq',
    'freq1_lambda',
    'freq1_rel_phase2',
    'freq1_rel_phase3',
    'freq1_rel_phase4',
    'freq1_signif',
    'freq2_amplitude1',
    'freq2_amplitude2',
    'freq2_amplitude3',
    'freq2_amplitude4',
    'freq2_freq',
    'freq2_rel_phase2',
    'freq2_rel_phase3',
    'freq2_rel_phase4',
    'freq3_amplitude1',
    'freq3_amplitude2',
    'freq3_amplitude3',
    'freq3_amplitude4',
    'freq3_freq',
    'freq3_rel_phase2',
    'freq3_rel_phase3',
    'freq3_rel_phase4',
    'freq_amplitude_ratio_21',
    'freq_amplitude_ratio_31',
    'freq_frequency_ratio_21',
    'freq_frequency_ratio_31',
    'freq_model_max_delta_mags',
    'freq_model_min_delta_mags',
    'freq_model_phi1_phi2',
    'freq_n_alias',
    'freq_signif_ratio_21',
    'freq_signif_ratio_31',
    'freq_varrat',
    'freq_y_offset',
    'linear_trend',
    'medperc90_2p_p',
    'p2p_scatter_2praw',
    'p2p_scatter_over_mad',
    'p2p_scatter_pfold_over_mad',
    'p2p_ssqr_diff_over_var',
    'scatter_res_raw',
]

np.warnings.filterwarnings('ignore')
lim = 10
train_feats_2 = featurize_time_series(t[:lim], v[:lim], e[:lim], features_to_use=feat_names)
# Out:
# CPU times: user 14.9 s, sys: 10.2 s, total: 25.1 s
# Wall time: 8.59 s

# %%
len(t[0])
# Out:
# 6

# %%
for f in train_feats.columns:
    print(f, train_feats[f].isna().sum())
# Out:
# ('amplitude', 0) 0
# ('amplitude', 1) 0
# ('amplitude', 2) 0
# ('amplitude', 3) 0
# ('amplitude', 4) 0
# ('amplitude', 5) 0
# ('flux_percentile_ratio_mid20', 0) 31
# ('flux_percentile_ratio_mid20', 1) 175
# ('flux_percentile_ratio_mid20', 2) 201
# ('flux_percentile_ratio_mid20', 3) 187
# ('flux_percentile_ratio_mid20', 4) 146
# ('flux_percentile_ratio_mid20', 5) 150
# ('flux_percentile_ratio_mid35', 0) 41
# ('flux_percentile_ratio_mid35', 1) 205
# ('flux_percentile_ratio_mid35', 2) 228
# ('flux_percentile_ratio_mid35', 3) 217
# ('flux_percentile_ratio_mid35', 4) 172
# ('flux_percentile_ratio_mid35', 5) 177
# ('flux_percentile_ratio_mid50', 0) 56
# ('flux_percentile_ratio_mid50', 1) 232
# ('flux_percentile_ratio_mid50', 2) 259
# ('flux_percentile_ratio_mid50', 3) 241
# ('flux_percentile_ratio_mid50', 4) 202
# ('flux_percentile_ratio_mid50', 5) 202
# ('flux_percentile_ratio_mid65', 0) 68
# ('flux_percentile_ratio_mid65', 1) 269
# ('flux_percentile_ratio_mid65', 2) 289
# ('flux_percentile_ratio_mid65', 3) 271
# ('flux_percentile_ratio_mid65', 4) 235
# ('flux_percentile_ratio_mid65', 5) 224
# ('flux_percentile_ratio_mid80', 0) 87
# ('flux_percentile_ratio_mid80', 1) 337
# ('flux_percentile_ratio_mid80', 2) 352
# ('flux_percentile_ratio_mid80', 3) 335
# ('flux_percentile_ratio_mid80', 4) 291
# ('flux_percentile_ratio_mid80', 5) 255
# ('max_slope', 0) 0
# ('max_slope', 1) 0
# ('max_slope', 2) 0
# ('max_slope', 3) 0
# ('max_slope', 4) 0
# ('max_slope', 5) 0
# ('maximum', 0) 0
# ('maximum', 1) 0
# ('maximum', 2) 0
# ('maximum', 3) 0
# ('maximum', 4) 0
# ('maximum', 5) 0
# ('median', 0) 0
# ('median', 1) 0
# ('median', 2) 0
# ('median', 3) 0
# ('median', 4) 0
# ('median', 5) 0
# ('median_absolute_deviation', 0) 0
# ('median_absolute_deviation', 1) 0
# ('median_absolute_deviation', 2) 0
# ('median_absolute_deviation', 3) 0
# ('median_absolute_deviation', 4) 0
# ('median_absolute_deviation', 5) 0
# ('minimum', 0) 0
# ('minimum', 1) 0
# ('minimum', 2) 0
# ('minimum', 3) 0
# ('minimum', 4) 0
# ('minimum', 5) 0
# ('percent_amplitude', 0) 17
# ('percent_amplitude', 1) 117
# ('percent_amplitude', 2) 114
# ('percent_amplitude', 3) 92
# ('percent_amplitude', 4) 80
# ('percent_amplitude', 5) 93
# ('percent_beyond_1_std', 0) 0
# ('percent_beyond_1_std', 1) 0
# ('percent_beyond_1_std', 2) 0
# ('percent_beyond_1_std', 3) 0
# ('percent_beyond_1_std', 4) 0
# ('percent_beyond_1_std', 5) 0
# ('percent_close_to_median', 0) 0
# ('percent_close_to_median', 1) 0
# ('percent_close_to_median', 2) 0
# ('percent_close_to_median', 3) 0
# ('percent_close_to_median', 4) 0
# ('percent_close_to_median', 5) 0
# ('percent_difference_flux_percentile', 0) 19
# ('percent_difference_flux_percentile', 1) 132
# ('percent_difference_flux_percentile', 2) 164
# ('percent_difference_flux_percentile', 3) 137
# ('percent_difference_flux_percentile', 4) 97
# ('percent_difference_flux_percentile', 5) 111
# ('period_fast', 0) 0
# ('period_fast', 1) 0
# ('period_fast', 2) 0
# ('period_fast', 3) 0
# ('period_fast', 4) 0
# ('period_fast', 5) 0
# ('qso_log_chi2_qsonu', 0) 0
# ('qso_log_chi2_qsonu', 1) 0
# ('qso_log_chi2_qsonu', 2) 0
# ('qso_log_chi2_qsonu', 3) 0
# ('qso_log_chi2_qsonu', 4) 0
# ('qso_log_chi2_qsonu', 5) 0
# ('qso_log_chi2nuNULL_chi2nu', 0) 0
# ('qso_log_chi2nuNULL_chi2nu', 1) 0
# ('qso_log_chi2nuNULL_chi2nu', 2) 0
# ('qso_log_chi2nuNULL_chi2nu', 3) 0
# ('qso_log_chi2nuNULL_chi2nu', 4) 0
# ('qso_log_chi2nuNULL_chi2nu', 5) 0
# ('skew', 0) 0
# ('skew', 1) 0
# ('skew', 2) 0
# ('skew', 3) 0
# ('skew', 4) 0
# ('skew', 5) 0
# ('std', 0) 0
# ('std', 1) 0
# ('std', 2) 0
# ('std', 3) 0
# ('std', 4) 0
# ('std', 5) 0
# ('stetson_j', 0) 0
# ('stetson_j', 1) 0
# ('stetson_j', 2) 0
# ('stetson_j', 3) 0
# ('stetson_j', 4) 0
# ('stetson_j', 5) 0
# ('stetson_k', 0) 0
# ('stetson_k', 1) 0
# ('stetson_k', 2) 0
# ('stetson_k', 3) 0
# ('stetson_k', 4) 0
# ('stetson_k', 5) 0
# ('weighted_average', 0) 0
# ('weighted_average', 1) 0
# ('weighted_average', 2) 0
# ('weighted_average', 3) 0
# ('weighted_average', 4) 0
# ('weighted_average', 5) 0

# %%
train_feats.to_hdf('data/training_feats/raw_cesium_feats.h5', 'w')

# %%
df = train_feats

flat_index = [f'{t[0]}_{t[1]}' for t in df.columns.to_series().str.join('').index.values]
df = df.astype(
    {feat_name_: np.float16 for feat_name_ in df.columns}
)
df.columns = pd.Index(flat_index)

# %%
nadf = df.isna().sum()
na_cols = list(nadf.index[nadf>0])
na_cols

df3 = df.drop(na_cols, axis=1)
df3.head()
df3.insert(0, 'object_id', uoids)
df3.to_hdf('data/training_feats/prep_cesium_feats_v2.h5', 'w')

# %%
df.insert(0, 'object_id', uoids)
df.head()
# Out:
#    object_id  amplitude_0  amplitude_1  amplitude_2  amplitude_3  amplitude_4  \
# 0        615   121.062500   880.500000   647.000000   488.250000   402.000000
# 1        713    14.625000    10.421875    10.296875    11.859375    11.054688
# 2        730     4.699219     4.542969    11.921875    19.500000    23.500000
# 3        745    10.945312    97.937500   111.500000   104.125000    99.562500
# 4       1124     6.066406    19.890625    54.375000    71.312500    80.062500
#
#    amplitude_5  flux_percentile_ratio_mid20_0  flux_percentile_ratio_mid20_1  \
# 0   400.500000                       0.000000                            NaN
# 1    14.492188                       0.003239                       0.001148
# 2    33.250000                       0.057281                       0.033813
# 3    75.875000                       0.027481                       0.078491
# 4    60.000000                       0.031799                       0.097839
#
#    flux_percentile_ratio_mid20_2         ...          stetson_k_2  \
# 0                       0.000000         ...             1.053711
# 1                       0.001888         ...             1.087891
# 2                       0.197998         ...             0.634766
# 3                       0.120850         ...             0.394775
# 4                       0.170654         ...             0.560547
#
#    stetson_k_3  stetson_k_4  stetson_k_5  weighted_average_0  \
# 0     1.112305     1.099609     1.125977          -17.062500
# 1     1.079102     1.104492     1.059570           -3.500000
# 2     0.640137     0.642090     0.803711           -0.016418
# 3     0.510254     0.520508     0.642578            1.176758
# 4     0.516113     0.498047     0.567383            0.824219
#
#    weighted_average_1  weighted_average_2  weighted_average_3  \
# 0         -212.375000         -102.250000         -101.187500
# 1           -1.322266           -1.030273           -1.382812
# 2           -0.034180            2.060547            2.988281
# 3            3.652344            6.718750           12.515625
# 4            3.617188            7.843750            8.828125
#
#    weighted_average_4  weighted_average_5
# 0          -54.750000          -59.687500
# 1           -1.408203           -1.875977
# 2            4.488281            5.058594
# 3           12.250000            8.757812
# 4            8.460938            5.601562
#
# [5 rows x 139 columns]

# %%
df2 = df.apply(lambda col : col.fillna(col.mean()))
df2.to_hdf('data/training_feats/prep_cesium_feats.h5', 'w')

# %%
df2.iloc[:15,:]
# Out:
#     object_id  amplitude_0  amplitude_1  amplitude_2  amplitude_3  \
# 0         615   121.062500   880.500000   647.000000   488.250000
# 1         713    14.625000    10.421875    10.296875    11.859375
# 2         730     4.699219     4.542969    11.921875    19.500000
# 3         745    10.945312    97.937500   111.500000   104.125000
# 4        1124     6.066406    19.890625    54.375000    71.312500
# 5        1227    37.750000     5.335938     2.910156     3.841797
# 6        1598   141.625000   726.000000   646.500000   503.000000
# 7        1632     4.496094     5.089844     3.521484     6.789062
# 8        1920    12.960938   101.812500   117.812500   114.812500
# 9        1926     7.113281     3.576172    16.484375     5.269531
# 10       2072     5.851562     7.687500    11.453125    11.304688
# 11       2103    51.500000   111.062500    69.187500    65.250000
# 12       2300     5.367188     3.855469     2.646484    11.000000
# 13       2330     7.093750     2.833984     4.175781     7.562500
# 14       2624    52.562500    26.953125    34.781250    74.937500
#
#     amplitude_4  amplitude_5  flux_percentile_ratio_mid20_0  \
# 0    402.000000   400.500000                       0.000000
# 1     11.054688    14.492188                       0.003239
# 2     23.500000    33.250000                       0.057281
# 3     99.562500    75.875000                       0.027481
# 4     80.062500    60.000000                       0.031799
# 5     10.914062    15.234375                       0.049225
# 6    371.250000   333.500000                       0.017288
# 7     11.437500    24.546875                       0.096130
# 8     98.687500    81.750000                       0.026871
# 9      8.585938    34.187500                       0.035614
# 10    11.718750    19.828125                       0.026428
# 11    71.812500    81.187500                       0.025620
# 12    16.062500    26.156250                       0.071960
# 13    15.351562    15.937500                       0.031891
# 14   954.000000   228.375000                       0.063171
#
#     flux_percentile_ratio_mid20_1  flux_percentile_ratio_mid20_2  \
# 0                        0.048004                       0.000000
# 1                        0.001148                       0.001888
# 2                        0.033813                       0.197998
# 3                        0.078491                       0.120850
# 4                        0.097839                       0.170654
# 5                        0.119019                       0.135742
# 6                        0.069214                       0.071716
# 7                        0.054230                       0.069458
# 8                        0.077942                       0.040314
# 9                        0.036194                       0.141479
# 10                       0.072815                       0.183960
# 11                       0.030365                       0.025116
# 12                       0.059814                       0.073181
# 13                       0.139648                       0.131470
# 14                       0.017670                       0.033539
#
#            ...          stetson_k_2  stetson_k_3  stetson_k_4  stetson_k_5  \
# 0          ...             1.053711     1.112305     1.099609     1.125977
# 1          ...             1.087891     1.079102     1.104492     1.059570
# 2          ...             0.634766     0.640137     0.642090     0.803711
# 3          ...             0.394775     0.510254     0.520508     0.642578
# 4          ...             0.560547     0.516113     0.498047     0.567383
# 5          ...             0.973145     1.051758     0.856445     0.930664
# 6          ...             0.241333     0.248047     0.251221     0.299561
# 7          ...             0.946289     0.971191     0.985840     0.915039
# 8          ...             0.484131     0.538574     0.567871     0.662598
# 9          ...             0.451660     1.030273     1.011719     0.938965
# 10         ...             0.749512     0.818848     0.896484     0.968750
# 11         ...             0.437256     0.449463     0.455566     0.544434
# 12         ...             0.976562     0.874512     0.873047     0.934082
# 13         ...             0.973145     0.879883     0.774414     0.923828
# 14         ...             0.373047     0.366943     0.190430     0.400635
#
#     weighted_average_0  weighted_average_1  weighted_average_2  \
# 0           -17.062500         -212.375000         -102.250000
# 1            -3.500000           -1.322266           -1.030273
# 2            -0.016418           -0.034180            2.060547
# 3             1.176758            3.652344            6.718750
# 4             0.824219            3.617188            7.843750
# 5             0.836914            0.356689           -0.044128
# 6            10.671875            2.025391            2.945312
# 7            -0.015915            0.151855            0.245117
# 8             2.580078           10.820312           17.390625
# 9             1.246094           -0.016022            1.571289
# 10            0.119141            1.843750            3.052734
# 11            2.351562            9.390625           10.296875
# 12            0.190552           -0.050293            0.405518
# 13            0.160645            0.082336            0.792480
# 14            2.158203            0.536133            0.566895
#
#     weighted_average_3  weighted_average_4  weighted_average_5
# 0          -101.187500          -54.750000          -59.687500
# 1            -1.382812           -1.408203           -1.875977
# 2             2.988281            4.488281            5.058594
# 3            12.515625           12.250000            8.757812
# 4             8.828125            8.460938            5.601562
# 5             0.264404            0.687988           -0.878418
# 6             5.015625            8.312500           13.929688
# 7             0.948242            2.863281            6.152344
# 8            25.843750           23.609375           19.734375
# 9             0.325684           -0.404297           -0.388184
# 10            2.058594            2.169922            1.900391
# 11           12.312500           12.859375           13.195312
# 12            4.152344            4.667969            4.839844
# 13            1.306641            1.257812            0.496338
# 14            2.287109            9.781250            6.062500
#
# [15 rows x 139 columns]
